# %% [markdown]
# # Travaux pratiques sur les réseaux d'eau

# %% [markdown]
# ## 0. Données et fonctions du problème

# %% [markdown]
# ### On charge dans l'environnement :
# 1. les fonctions de Python qui seront utilisées,
# 2. les données du problème,
# 3. les fonctions utilitaires du problème.

# %%
from numpy import random
import numpy as np

# %%
from Probleme_R import *
from Structures_N import *

# %%
from Visualg import Visualg
from Verification import Verification

# %% [markdown]
# ###  On charge les prototypes d'algorithmes d'optimisation :
#
# * **Gradient_F** : algorithme de gradient à pas fixe,
# * **Newton_F** : algorithme de Newton à pas fixe.

# %%
def Gradient_F(Oracle, x0, alpha0):
    
    from numpy.linalg import norm
    from time import process_time
    
    ##### Initialisation des variables
    
    iter_max = 10000
    gradient_step = alpha0
    threshold = 0.000001
    
    gradient_norm_list = []
    gradient_step_list = []

    critere_list = []
    
    time_start = process_time()
    
    x = x0

    ##### Boucle sur les iterations

    for k in range(iter_max):
        
        # Valeur du critere et du gradient
        critere, gradient = Oracle(x)
        
        # Test de convergence
        gradient_norm = norm(gradient)
        if gradient_norm <= threshold:
            break

        # Direction de descente
        direction = -gradient
        
        # Backracking Line search for step size
        #gradient_step = BacktrackingLineSearch(x,critere,gradient,direction)
        
        # Mise a jour des variables
        x = x + (gradient_step*direction)
        
        # Evolution du gradient, du pas, et du critere
        gradient_norm_list.append(gradient_norm)
        gradient_step_list.append(gradient_step)

        
        critere_list.append(critere)
    
    ##### Resultats de l'optimisation

    critere_opt = critere
    gradient_opt = gradient
    x_opt = x
    time_cpu = process_time() - time_start
    
    print()
    print('Iteration :', k)
    print('Temps CPU :', time_cpu)
    print('Critere optimal :', critere_opt)
    print('Norme du gradient :', norm(gradient_opt))

    # Visualisation de la convergence
    Visualg(gradient_norm_list, gradient_step_list, critere_list)
    
    return critere_opt, gradient_opt, x_opt, gradient_norm_list, gradient_step_list, critere_list

# %%
def Newton_F(Oracle, x0, alpha0):
    
    from numpy.linalg import norm
    from numpy.linalg import solve
    from time import process_time
    
    ##### Initialisation des variables    
    
    iter_max = 100
    gradient_step = alpha0
    threshold = 0.000001
    
    gradient_norm_list = []
    gradient_step_list = []
    critere_list = []

    time_start = process_time()
    
    x = x0

    ##### Boucle sur les iterations
    
    for k in range(iter_max):
        
        # Valeur du critere et du gradient
        critere, gradient, hessien = Oracle(x)

        # Test de convergence
        gradient_norm = norm(gradient)
        if gradient_norm <= threshold:
            break
        
        # Direction de descente
        direction = - solve(hessien, gradient)
        
        # Mise a jour des variables
        x = x + (gradient_step*direction)
        
        # Evolution du gradient, du pas, et du critere
        gradient_norm_list.append(gradient_norm)
        gradient_step_list.append(gradient_step)
        critere_list.append(critere)
   
    ##### Resultats de l'optimisation
    
    critere_opt = critere
    gradient_opt = gradient
    x_opt = x
    time_cpu = process_time() - time_start

    print()
    print('Iteration :', k)
    print('Temps CPU :', time_cpu)
    print('Critere optimal :', critere_opt)
    print('Norme du gradient :', norm(gradient_opt))
    
    # Visualisation de la convergence
    Visualg(gradient_norm_list, gradient_step_list, critere_list)
    
    return critere_opt, gradient_opt, x_opt,gradient_norm_list, gradient_step_list, critere_list

# %% [markdown]
# ## I. Résolution du problème primal

# %%
from HydrauliqueP import HydrauliqueP

# %% [markdown]
# ### I.a On écrit les oracles pour le problème primal d'optimisation :
#
# * **OraclePG** : calcul de la fonction et du gradient,
# * **OraclePH** : calcul de la fonction du gradient et du Hessien.

# %% [markdown]
# $ q=q^{(0)}+B q_{c} $
#
# $ z=r \bullet q \bullet|q| $
#
# $ \nabla F\left(q_{C}\right)=B^{\top}(r \bullet q \bullet|q|)+B^{\top} A_{r}^{\top} p_{r} $
#
# $ F\left(q_{C}\right) = \frac{1}{3}\langle q, r \bullet q \bullet|q|\rangle+\left\langle p_{r}, A_{r} q\right\rangle $

# %%
def OraclePG(qc):
    
    gradient =B.transpose()@(r*(q0+B@qc)*abs(q0+B@qc))+B.transpose()@Ar.transpose()@pr
    critere = dot(q0+B@qc, r*(q0+B@qc)*abs(q0+B@qc))/3 + dot(pr, Ar@(q0+B@qc))
    
    return critere, gradient

# %% [markdown]
# $ \nabla^{2} F\left(q_{c}\right)=2B^{T} \operatorname{diag}(\mathrm{r} \cdot|q| ) \mathrm{B} $

# %%
def OraclePH(qc):
    q = q0 + B@qc 
    M =2 * np.diag(r * abs(q))
    temp = B.T.dot(M)
    hessien = temp.dot(B)
    critere, gradient= OraclePG(qc)
    # ---> A COMPLETER
    # ---> A COMPLETER
    
    return critere, gradient, hessien

# %% [markdown]
# ### On teste la validité des oracles en résolvant le problème :
#
# * **OraclePG** avec la méthode du gradient à pas fixe,
# * **OraclePH** avec la méthode de Newton à pas fixe

# %%
x0 = 0.1 * random.normal(size=n-md)
print()
print("MINIMISATION DU PROBLEME PRIMAL")
print()
print("ALGORITHME DU GRADIENT A PAS FIXE")
copt, gopt, xopt,gnl_GF, gsl_GF, cl_GF = Gradient_F(OraclePG, x0, 0.0005)
qopt, zopt, fopt, popt = HydrauliqueP(xopt, m, mr, md, r, pr, fd, Ar, AdI, B, q0)
Verification(A, qopt, zopt, fopt, popt)
# Out:
# MINIMISATION DU PROBLEME PRIMAL
#
# ALGORITHME DU GRADIENT A PAS FIXE
#
# Iteration : 4259
# Temps CPU : 0.15625
# Critere optimal : -3.7340070480435
# Norme du gradient : 9.970512626790383e-07
# Verification des equations d'equilibre du reseau
# Sur les debits : 2.220446049250313e-16
# Sur les pressions : 9.970463732411616e-07

# %% [markdown]
# - Input variables
#   1. $ gradient \ list$: array containing the norm of the gradient  of the criterion at each iteration of the optimization algorithm.
#   2. $ step \ list $: array containing the length of the gradient step at each iteration.
#   3. $ criterere \ list$: array containing the value of the criterion

# %%
x0 = 0.1 * random.normal(size=n-md)
print()
print("MINIMISATION DU PROBLEME PRIMAL")
print()
print("ALGORITHME DE NEWTON A PAS FIXE")
copt, gopt, xopt,gnl_NF, gsl_NF, cl_NF  = Newton_F(OraclePH, x0, 1)
qopt, zopt, fopt, popt = HydrauliqueP(xopt, m, mr, md, r, pr, fd, Ar, AdI, B, q0)
Verification(A, qopt, zopt, fopt, popt)
# Out:
# MINIMISATION DU PROBLEME PRIMAL
#
# ALGORITHME DE NEWTON A PAS FIXE
#
# Iteration : 6
# Temps CPU : 0.0
# Critere optimal : -3.7340070480435745
# Norme du gradient : 2.375101846940889e-11
# Verification des equations d'equilibre du reseau
# Sur les debits : 1.6653345369377348e-16
# Sur les pressions : 2.1506511849178622e-11

# %% [markdown]
# ### Gradient descending algorithm with optimal stepsize by exact line search

# %% [markdown]
# Exact line search
# $$ t=\operatorname{argmin}_{s \geq 0} f(x+s \Delta x) $$

# %%
from scipy.optimize import line_search

# %%
def F(x):
    #print("in F",x)
    return dot(q0+B@x, r*(q0+B@x)*abs(q0+B@x))/3 + dot(pr, Ar@(q0+B@x))

def G(x):
    #print("in G",x)
    return B.transpose()@(r*(q0+B@x)*abs(q0+B@x))+B.transpose()@Ar.transpose()@pr
def Exact_line_earch(F,G,x0,direction):
    #print(F)
    #print(G)
    #critere = dot(q0+B@qc, r*(q0+B@qc)*abs(q0+B@qc))/3 + dot(pr, Ar@(q0+B@qc))
    #gradient = B.transpose()@(r*(q0+B@qc)*abs(q0+B@qc))+B.transpose()@Ar.transpose()@pr
    start_point = x0
    search_direction = direction
    #print(x0)
    #print(x0.shape)
    #print(gradient)
    #print(gradient.shape)
    res = line_search(F, G, start_point,  search_direction, maxiter = 10 )
    return res

# %%
def Gradient_L(F,G,Oracle, x0, alpha0):
    
    from numpy.linalg import norm
    from time import process_time
    
    ##### Initialisation des variables
    
    iter_max = 10000
    gradient_step = alpha0
    threshold = 0.000001
    
    gradient_norm_list = []
    gradient_step_list = []

    critere_list = []
    x_list = []
    
    time_start = process_time()
    
    x = x0

    ##### Boucle sur les iterations

    for k in range(iter_max):
        
        # Valeur du critere et du gradient
        critere, gradient = Oracle(x)
        
        # Test de convergence
        gradient_norm = norm(gradient)
        if gradient_norm <= threshold:
            break

        # Direction de descente
        direction = -gradient
        
        # Exact Line search for step size
        if k > 0:
            res = Exact_line_earch(F,G,x,direction)
            
            #print(res)
            if res[0] is not None:
                gradient_step = res[0]
                
                
            else:
                gradient_step  =  gradient_step_list[-1]
                #print(k)
                #print(gradient_step)
                
        #gradient_step = BacktrackingLineSearch(x,critere,gradient,direction)
        #print()
        # Mise a jour des variables
        x_list.append(x)
        x = x + (gradient_step*direction)
        
        # Evolution du gradient, du pas, et du critere
        gradient_norm_list.append(gradient_norm)
        gradient_step_list.append(gradient_step)

        
        critere_list.append(critere)
    
    ##### Resultats de l'optimisation

    critere_opt = critere
    gradient_opt = gradient
    x_opt = x
    time_cpu = process_time() - time_start
    
    print()
    print('Iteration :', k)
    print('Temps CPU :', time_cpu)
    print('Critere optimal :', critere_opt)
    print('Norme du gradient :', norm(gradient_opt))

    # Visualisation de la convergence
    Visualg(gradient_norm_list, gradient_step_list, critere_list)
    
    return critere_opt, gradient_opt, x_opt, gradient_norm_list, gradient_step_list, critere_list

# %%
x0 = 0.1 * random.normal(size=n-md)
print()
print("MINIMISATION DU PROBLEME PRIMAL")
print()
print("ALGORITHME DU GRADIENT A PAS OPT")
copt, gopt, xopt,gnl_GF, gsl_GF, cl_GF = Gradient_L(F,G,OraclePG, x0, 0.0005)
qopt, zopt, fopt, popt = HydrauliqueP(xopt, m, mr, md, r, pr, fd, Ar, AdI, B, q0)
Verification(A, qopt, zopt, fopt, popt)
# Out:
# MINIMISATION DU PROBLEME PRIMAL
#
# ALGORITHME DU GRADIENT A PAS OPT
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\optimize\linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# Iteration : 1055
# Temps CPU : 0.5
# Critere optimal : -3.734007048043514
# Norme du gradient : 9.935411882831216e-07
# Verification des equations d'equilibre du reseau
# Sur les debits : 1.6653345369377348e-16
# Sur les pressions : 9.047802753681111e-07

# %% [markdown]
# ### Gradient descending algorithm with optimal stepsize by Wolf algorithm

# %% [markdown]
# - Notation
# $ x^{k}$
# $g^{k}$ : $ \nabla f(x) $
# $ d^{k}$ : $ \Delta x^{k} $
# $ \alpha^{(k)} $: $t^{k}$

# %% [markdown]
# - condition
# $$ f\left(x^{(k)}+\alpha^{(k)} d^{(k)}\right) \leq f\left(x^{(k)}\right)+\omega_{1} \alpha^{(k)} g^{(k)^{\top}} d^{(k)} $$
# $ \Leftrightarrow $
# $$ f(x^{k}+t^{k} \Delta x^{k})>f(x^{k})+ t^{k} \nabla f(x^{k})^{T} \Delta x^{k} $$
# $$ \left(\nabla f\left(x^{(k)}+\alpha^{(k)} d^{(k)}\right)\right)^{\top} d^{(k)} \geq \omega_{2} g^{(k)^{\top}} d^{(k)} $$
# where $ 0<\omega_{1}<\omega_{2}<1 $

# %%
def Wolfe(alpha, x, D, Oracle):
    
    from numpy import dot
    from numpy import inf
    from numpy.linalg import norm

    ##### Coefficients de la recherche lineaire
    
    omega_1 = 0.1
    omega_2 = 0.9
    
    alpha_min = 0
    alpha_max = inf
    
    ok = 0
    dltx = 0.00000001

    ##### Algorithme de Fletcher-Lemarechal
    
    # Appel de l'oracle au point initial
    #print(Oracle)
    res = Oracle(x)
    critere = res[0]
    gradient = res[1]
    
    # Initialisation de l'algorithme
    alpha_n = alpha
    xn = x
    
    # Boucle de calcul du pas
    # xn represente le point pour la valeur courante du pas,
    # xp represente le point pour la valeur precedente du pas.
    while ok == 0:
        
        # Point precedent pour tester l'indistinguabilite
        xp = xn
        
        # Point actuel
        xn = x + alpha_n*D
        #print("xn: ",xn)
        
        # Calculation of Wolfe conditions
        
        # f(x^k+t^k d^k) gradient_f(x^k+t^k d^k)
        
        res_n = Oracle(xn)
        critere_n = res_n[0]
        gradient_n = res_n[1]
        
        #print("critere_n",critere_n)
        #print("gradient_n",gradient_n)
        # condition 1
        condition1 = (critere_n <= critere+omega_1*alpha_n*gradient.transpose()@D)
        
        # condition 2
        #print(critere_n.transpose())
        #print(D)
        condition2 = (gradient_n.transpose()@D >= omega_2*gradient.transpose()@D)
        
        # ---> To be completed ...
        # ---> To be completed ...
        
        # Test of Wolfe conditions
        #
        # - If both Wolfe conditions are true,
        # set ok = 1: we then exit the while loop
        if condition1 and condition2:
            
            ok = 1
            
        
        # - Otherwise, modify the value of alphan and loop back
        else:
            if not condition1:
                alpha_max = alpha_n
                alpha_n = 1/2 * (alpha_min+alpha_max)
            if not condition2:
                alpha_min = alpha_n
                if alpha_max == inf:
                    alpha_n = 2*alpha_min
                else:
                    alpha_n = 1/2 * (alpha_min+alpha_max)
        
            
            
        # ---> To be completed ...
        # ---> To be completed ...
        
        # Test d'indistinguabilite
        if norm(xn - xp) < dltx:
            ok = 2

    return alpha_n, ok

# %%
def Gradient_V(Oracle, x0, alpha0):
    
    from numpy.linalg import norm
    from time import process_time
    
    ##### Initialisation des variables

    iter_max = 1000
    default_gradient_step = alpha0
    threshold = 0.000001
    
    gradient_norm_list = []
    gradient_step_list = []
    critere_list = []
    
    time_start = process_time()

    x = x0

    ##### Boucle sur les iterations

    for k in range(iter_max):
        
        # ---> A COMPLETER
        # ---> A COMPLETER
        
        # Valeur du critere et du gradient
        critere, gradient = Oracle(x)
        
        # Test de convergence
        gradient_norm = norm(gradient)
        if gradient_norm <= threshold:
            break

        # Direction de descente
        direction = -gradient
        
        # conditions de Wolfe for step size
        res = Wolfe(default_gradient_step, x, direction, Oracle)
        gradient_step = res[0]
        #print("gradient_n",gradient_step)
        # Mise a jour des variables
        x = x + (gradient_step*direction)
        
        # Evolution du gradient, du pas, et du critere
        gradient_norm_list.append(gradient_norm)
        gradient_step_list.append(gradient_step)

        
        critere_list.append(critere)
    ##### Resultats de l'optimisation
    critere_opt = critere
    gradient_opt = gradient
    x_opt = x
    time_cpu = process_time() - time_start

    print()
    print('Iteration :', k)
    print('Temps CPU :', time_cpu)
    print('Critere optimal :', critere_opt)
    print('Norme du gradient :', norm(gradient_opt))
    
    # Visualisation de la convergence
    Visualg(gradient_norm_list, gradient_step_list, critere_list)
    
    return critere_opt, gradient_opt, x_opt,gradient_norm_list, gradient_step_list, critere_list

# %%
x0 = 0.1 * random.normal(size=n-md)
print()
print("MINIMISATION DU PROBLEME PRIMAL")
print()
print("ALGORITHME DU GRADIENT A PAS VARIABLE")
copt, gopt, xopt,gnl_GV, gsl_GV, cl_GV = Gradient_V(OraclePG, x0, 1)
qopt, zopt, fopt, popt = HydrauliqueP(xopt, m, mr, md, r, pr, fd, Ar, AdI, B, q0)
Verification(A, qopt, zopt, fopt, popt)
# Out:
# MINIMISATION DU PROBLEME PRIMAL
#
# ALGORITHME DU GRADIENT A PAS VARIABLE
#
# Iteration : 280
# Temps CPU : 0.15625
# Critere optimal : -3.734007048043523
# Norme du gradient : 8.811139192432331e-07
# Verification des equations d'equilibre du reseau
# Sur les debits : 1.1102230246251565e-16
# Sur les pressions : 8.371874834489645e-07

# %% [markdown]
# ### Conjugation gradient descending algorithm with fixed stepsize

# %% [markdown]
# $ d^{(k)}=\left\{\begin{array}{ll}-g^{(1)} & \text { si } k=1 \\ -g^{(k)}+\beta^{(k)} d^{(k-1)} & \text { sinon }\end{array}\right. $

# %% [markdown]
# $ \beta^{(k)}=\frac{g^{(k)^{\top}}\left(g^{(k)}-g^{(k-1)}\right)}{\| g^{(k-1) \|^{2}}} $

# %%
def PolakRibiere(Oracle, x0, alpha0):
    
    from numpy import dot
    from numpy.linalg import norm
    from time import process_time
    
    ##### Initialisation des variables

    iter_max = 10000
    default_gradient_step = alpha0
    threshold = 0.000001
    
    gradient_norm_list = []
    gradient_step_list = []
    gradient_list = []
    critere_list = []
    
    time_start = process_time()

    x = x0
    
    ##### Boucle sur les iterations
    
    for k in range(iter_max):
        
        
        # Valeur du critere et du gradient
        critere, gradient = Oracle(x)
        
        
        # Test de convergence
        gradient_norm = norm(gradient)
        if gradient_norm <= threshold:
            break
        
        # Formule de Polak-Ribi`ere for Direction de descente
        if k == 0:
            direction = -gradient
        else:
            #print("k:", k)
            #print("gradient_list: ",gradient_list)
            #print("gradient_norm_list:",gradient_norm_list)
            beta = gradient.transpose()@(gradient - gradient_list[-1])/(gradient_norm_list[-1] * gradient_norm_list[-1])
            direction = -gradient + beta*direction

        # conditions de Wolfe for step size
        #res = Wolfe(default_gradient_step, x, direction, Oracle)
        #gradient_step = res[0]
        gradient_step =  default_gradient_step
        
        # Mise a jour des variables
        x = x + (gradient_step*direction)
        
        # Evolution du gradient, du pas, et du critere
        gradient_norm_list.append(gradient_norm)
        gradient_step_list.append(gradient_step)
        gradient_list.append(gradient)

        
        critere_list.append(critere)
    
    # Resultat de l'optimisation
    critere_opt = critere
    gradient_opt = gradient
    x_opt = x
    time_cpu = process_time() - time_start

    print()
    print('Iteration :', k)
    print('Temps CPU :', time_cpu)
    print('Critere optimal :', critere_opt)
    print('Norme du gradient :', norm(gradient_opt))
        
    # Visualisation de la convergence
    Visualg(gradient_norm_list, gradient_step_list, critere_list)
    
    return critere_opt, gradient_opt, x_opt,gradient_norm_list, gradient_step_list, critere_list

# %%
x0 = 0.1 * random.normal(size=n-md)
print()
print("MINIMISATION DU PROBLEME PRIMAL")
print()
print("ALGORITHME DU GRADIENT CONJUGUE")
copt, gopt, xopt,gnl_GC, gsl_GC, cl_GC = PolakRibiere(OraclePG, x0, 0.0005)
qopt, zopt, fopt, popt = HydrauliqueP(xopt, m, mr, md, r, pr, fd, Ar, AdI, B, q0)
Verification(A, qopt, zopt, fopt, popt)
# Out:
# MINIMISATION DU PROBLEME PRIMAL
#
# ALGORITHME DU GRADIENT CONJUGUE
#
# Iteration : 3882
# Temps CPU : 0.15625
# Critere optimal : -3.7340070480435053
# Norme du gradient : 9.999713815264579e-07
# Verification des equations d'equilibre du reseau
# Sur les debits : 8.326672684688674e-17
# Sur les pressions : 9.99966914716488e-07

# %% [markdown]
# ### Conjugation gradient descending algorithm with optimal stepsize by Wolf algorithm

# %%
def PolakRibiereV(Oracle, x0, alpha0):
    
    from numpy import dot
    from numpy.linalg import norm
    from time import process_time
    
    ##### Initialisation des variables

    iter_max = 1000
    default_gradient_step = alpha0
    threshold = 0.000001
    
    gradient_norm_list = []
    gradient_step_list = []
    gradient_list = []
    critere_list = []
    
    time_start = process_time()

    x = x0
    
    ##### Boucle sur les iterations
    
    for k in range(iter_max):
        
        
        # Valeur du critere et du gradient
        critere, gradient = Oracle(x)
        
        
        # Test de convergence
        gradient_norm = norm(gradient)
        if gradient_norm <= threshold:
            break
        
        # Formule de Polak-Ribi`ere for Direction de descente
        if k == 0:
            direction = -gradient
        else:
            #print("k:", k)
            #print("gradient_list: ",gradient_list)
            #print("gradient_norm_list:",gradient_norm_list)
            beta = gradient.transpose()@(gradient - gradient_list[-1])/(gradient_norm_list[-1] * gradient_norm_list[-1])
            direction = -gradient + beta*direction

        # conditions de Wolfe for step size
        res = Wolfe(default_gradient_step, x, direction, Oracle)
        gradient_step = res[0]
        #gradient_step =  default_gradient_step
        
        # Mise a jour des variables
        x = x + (gradient_step*direction)
        
        # Evolution du gradient, du pas, et du critere
        gradient_norm_list.append(gradient_norm)
        gradient_step_list.append(gradient_step)
        gradient_list.append(gradient)

        
        critere_list.append(critere)
    
    # Resultat de l'optimisation
    critere_opt = critere
    gradient_opt = gradient
    x_opt = x
    time_cpu = process_time() - time_start

    print()
    print('Iteration :', k)
    print('Temps CPU :', time_cpu)
    print('Critere optimal :', critere_opt)
    print('Norme du gradient :', norm(gradient_opt))
        
    # Visualisation de la convergence
    Visualg(gradient_norm_list, gradient_step_list, critere_list)
    
    return critere_opt, gradient_opt, x_opt,gradient_norm_list, gradient_step_list, critere_list

# %%
x0 = 0.1 * random.normal(size=n-md)
print()
print("MINIMISATION DU PROBLEME PRIMAL")
print()
print("ALGORITHME DU GRADIENT CONJUGUE")
copt, gopt, xopt,gnl_GC, gsl_GC, cl_GC = PolakRibiereV(OraclePG, x0, 1)
qopt, zopt, fopt, popt = HydrauliqueP(xopt, m, mr, md, r, pr, fd, Ar, AdI, B, q0)
Verification(A, qopt, zopt, fopt, popt)
# Out:
# MINIMISATION DU PROBLEME PRIMAL
#
# ALGORITHME DU GRADIENT CONJUGUE
#
# Iteration : 253
# Temps CPU : 0.234375
# Critere optimal : -3.734007048043569
# Norme du gradient : 8.976934796526165e-07
# Verification des equations d'equilibre du reseau
# Sur les debits : 1.1102230246251565e-16
# Sur les pressions : 4.758987130482062e-07

# %% [markdown]
# ### Conjugation gradient descending algorithm with optimal stepsize by exact line search

# %%
def PolakRibiereL(Oracle, x0, alpha0):
    
    from numpy import dot
    from numpy.linalg import norm
    from time import process_time
    
    ##### Initialisation des variables

    iter_max = 1000
    gradient_step = alpha0
    threshold = 0.000001
    
    gradient_norm_list = []
    gradient_step_list = []
    gradient_list = []
    critere_list = []
    
    time_start = process_time()

    x = x0
    
    ##### Boucle sur les iterations
    
    for k in range(iter_max):
        
        
        # Valeur du critere et du gradient
        critere, gradient = Oracle(x)
        
        
        # Test de convergence
        gradient_norm = norm(gradient)
        if gradient_norm <= threshold:
            break
        
        # Formule de Polak-Ribi`ere for Direction de descente
        if k == 0:
            direction = -gradient
        else:
            #print("k:", k)
            #print("gradient_list: ",gradient_list)
            #print("gradient_norm_list:",gradient_norm_list)
            beta = gradient.transpose()@(gradient - gradient_list[-1])/(gradient_norm_list[-1] * gradient_norm_list[-1])
            direction = -gradient + beta*direction

        # conditions de Wolfe for step size
        #res = Wolfe(default_gradient_step, x, direction, Oracle)
        #gradient_step = res[0]
        
        # Exact Line search for step size
        if k > 0:
            res = Exact_line_earch(F,G,x,direction)
            
            #print(res)
            if res[0] is not None:
                gradient_step = res[0]
                
                
            else:
                gradient_step  =  gradient_step_list[-1]
                print(k)
                print(gradient_step)    
        
        # Mise a jour des variables
        x = x + (gradient_step*direction)
        
        # Evolution du gradient, du pas, et du critere
        gradient_norm_list.append(gradient_norm)
        gradient_step_list.append(gradient_step)
        gradient_list.append(gradient)

        
        critere_list.append(critere)
    
    # Resultat de l'optimisation
    critere_opt = critere
    gradient_opt = gradient
    x_opt = x
    time_cpu = process_time() - time_start

    print()
    print('Iteration :', k)
    print('Temps CPU :', time_cpu)
    print('Critere optimal :', critere_opt)
    print('Norme du gradient :', norm(gradient_opt))
        
    # Visualisation de la convergence
    Visualg(gradient_norm_list, gradient_step_list, critere_list)
    
    return critere_opt, gradient_opt, x_opt,gradient_norm_list, gradient_step_list, critere_list

# %%
x0 = 0.1 * random.normal(size=n-md)
print()
print("MINIMISATION DU PROBLEME PRIMAL")
print()
print("ALGORITHME DU GRADIENT CONJUGUE")
copt, gopt, xopt,gnl_GC, gsl_GC, cl_GC = PolakRibiereL(OraclePG, x0, 0.0005)
qopt, zopt, fopt, popt = HydrauliqueP(xopt, m, mr, md, r, pr, fd, Ar, AdI, B, q0)
Verification(A, qopt, zopt, fopt, popt)
# Out:
# MINIMISATION DU PROBLEME PRIMAL
#
# ALGORITHME DU GRADIENT CONJUGUE
# 2
# 0.008285268306861136
# 3
# 0.008285268306861136
# 4
# 0.008285268306861136
# 5
# 0.008285268306861136
# 6
# 0.008285268306861136
# <ipython-input-12-ad96acd04c62>:3: RuntimeWarning: overflow encountered in multiply
#   return dot(q0+B@x, r*(q0+B@x)*abs(q0+B@x))/3 + dot(pr, Ar@(q0+B@x))
# <ipython-input-7-1052a0dc5e65>:3: RuntimeWarning: invalid value encountered in matmul
#   gradient =B.transpose()@(r*(q0+B@qc)*abs(q0+B@qc))+B.transpose()@Ar.transpose()@pr
# <ipython-input-7-1052a0dc5e65>:4: RuntimeWarning: overflow encountered in multiply
#   critere = dot(q0+B@qc, r*(q0+B@qc)*abs(q0+B@qc))/3 + dot(pr, Ar@(q0+B@qc))
# <ipython-input-12-ad96acd04c62>:7: RuntimeWarning: overflow encountered in multiply
#   return B.transpose()@(r*(q0+B@x)*abs(q0+B@x))+B.transpose()@Ar.transpose()@pr
# <ipython-input-12-ad96acd04c62>:7: RuntimeWarning: invalid value encountered in matmul
#   return B.transpose()@(r*(q0+B@x)*abs(q0+B@x))+B.transpose()@Ar.transpose()@pr
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\optimize\linesearch.py:477: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# Iteration : 999
# Temps CPU : 0.421875
# Critere optimal : nan
# Norme du gradient : nan
# Verification des equations d'equilibre du reseau
# Sur les debits : nan
# Sur les pressions : nan

# %% [markdown]
# ### Quasi Newton method with fixed stepsize

# %% [markdown]
# $ d^{(k)}=-W^{(k)} g^{(k)} $
# $ \delta_{x}^{(k)}=x^{(k)}-x^{(k-1)} $
# $ \delta_{g}^{(k)}=g^{(k)}-g^{(k-1)} $
# $ W^{(k)}=\left(I-\frac{\delta_{x}^{(k)} \delta_{g}^{(k)} \top}{\delta_{g}^{(k)^{\top}} \delta_{x}^{(k)}}\right) W^{(k-1)}\left(I-\frac{\delta_{g}^{(k)} \delta_{x}^{(k)} \top}{\delta_{g}^{(k)^{\top}} \delta_{x}^{(k)}}\right)+\frac{\left.\delta_{x}^{(k)} \delta_{x}^{(k)}\right)^{\top}}{\delta_{g}^{(k)} \delta_{x}^{(k)}} $

# %%
def BFGS(Oracle, x0, alpha0):
    import numpy as np
    from numpy.linalg import solve
    from numpy import dot
    from numpy import eye
    from numpy import outer
    from numpy import vdot
    from numpy.linalg import norm
    from time import process_time
    
    ##### Initialisation des variables

    iter_max = 250
    default_gradient_step = alpha0
    threshold = 0.000001
    
    gradient_norm_list = []
    gradient_step_list = []
    gradient_list = []
    critere_list = []
    x_list = []
    
    time_start = process_time()

    x = x0
    I = eye(len(x0))
    
    ##### Boucle sur les iterations
    
    for k in range(iter_max):
        
        
        # Valeur du critere et du gradient
        res = Oracle(x)
        critere = res[0]
        gradient = res[1]
        #hessien = res[2]
        
        # Test de convergence
        gradient_norm = norm(gradient)
        if gradient_norm <= threshold:
            break
                # Valeur du critere et du gradient
        
        # Direction de descente
        #direction_n = - solve(hessien, gradient)
        #print("direction_n",direction_n)
        
        # Formule de BFGS inverse for Direction de descente
        #print("k:",k)
        if k == 0:
            Wk = I 
            #print("Wk",Wk)
        else:
            #print("gradient",gradient)
            #print("gradient_list[-1]",gradient_list[-1])
            delta_xk = np.array([list(x - x_list[-1])]).transpose()
            delta_gk = np.array([list(gradient - gradient_list[-1])]).transpose()
            
            #print("delta_xk",delta_xk)
            #print("delta_gk",delta_gk)
            
            #print("(delta_xk@delta_gk.transpose())",(delta_xk@delta_gk.transpose()))
            
            A = I - np.multiply(delta_xk,delta_gk.transpose())/(delta_gk.transpose()@delta_xk)
            B = I - np.multiply(delta_gk,delta_xk.transpose())/(delta_gk.transpose()@delta_xk)
            C = (np.multiply(delta_xk,delta_xk.transpose()))/(delta_gk.transpose()@delta_xk)
            #print("A:",A)
            #print("B:",B)
            #print("C:",C)
                        
            Wk = A@Wk@B + C


            #print("Wk",Wk)
            #print("Hessien", hessien)
        direction = -Wk@gradient
        #print("direction",direction)
        
        # Direction de descente
        #direction = - solve(hessien, gradient)
        
        # conditions de Wolfe for step size
        #res = Wolfe(default_gradient_step, x, direction, Oracle)
        #gradient_step = res[0]
        
        gradient_step =  default_gradient_step

        
        # Mise a jour des variables
        x_list.append(x)
        x = x + (gradient_step*direction)
        
        # Evolution du gradient, du pas, et du critere
        gradient_norm_list.append(gradient_norm)
        gradient_step_list.append(gradient_step)
        gradient_list.append(gradient)
        critere_list.append(critere)
    
    # Resultat de l'optimisation
    critere_opt = critere
    gradient_opt = gradient
    x_opt = x
    time_cpu = process_time() - time_start

    print()
    print('Iteration :', k)
    print('Temps CPU :', time_cpu)
    print('Critere optimal :', critere_opt)
    print('Norme du gradient :', norm(gradient_opt))
        
    # Visualisation de la convergence
    Visualg(gradient_norm_list, gradient_step_list, critere_list)
    
    return critere_opt, gradient_opt, x_opt,gradient_norm_list, gradient_step_list, critere_list

# %%
x0 = 0.1 * random.normal(size=n-md)
print()
print("MINIMISATION DU PROBLEME PRIMAL")
print()
print("ALGORITHME DE QUASI-NEWTON")
copt, gopt, xopt,gnl_QN, gsl_QN, cl_QN = BFGS(OraclePG, x0, 1)
#copt, gopt, xopt = Newton_N(OraclePH, x0, 1)
qopt, zopt, fopt, popt = HydrauliqueP(xopt, m, mr, md, r, pr, fd, Ar, AdI, B, q0)
Verification(A, qopt, zopt, fopt, popt)
# Out:
# MINIMISATION DU PROBLEME PRIMAL
#
# ALGORITHME DE QUASI-NEWTON
#
# Iteration : 249
# Temps CPU : 0.03125
# Critere optimal : nan
# Norme du gradient : nan
# <ipython-input-7-1052a0dc5e65>:3: RuntimeWarning: overflow encountered in multiply
#   gradient =B.transpose()@(r*(q0+B@qc)*abs(q0+B@qc))+B.transpose()@Ar.transpose()@pr
# <ipython-input-7-1052a0dc5e65>:3: RuntimeWarning: invalid value encountered in matmul
#   gradient =B.transpose()@(r*(q0+B@qc)*abs(q0+B@qc))+B.transpose()@Ar.transpose()@pr
# <ipython-input-7-1052a0dc5e65>:4: RuntimeWarning: overflow encountered in multiply
#   critere = dot(q0+B@qc, r*(q0+B@qc)*abs(q0+B@qc))/3 + dot(pr, Ar@(q0+B@qc))
# <ipython-input-24-dff377ab0e14>:67: RuntimeWarning: overflow encountered in multiply
#   C = (np.multiply(delta_xk,delta_xk.transpose()))/(delta_gk.transpose()@delta_xk)
# Verification des equations d'equilibre du reseau
# Sur les debits : nan
# Sur les pressions : nan

# %% [markdown]
# ### Quasi Newton method with optimal stepsize by Wolf algorithm

# %%
def BFGS_V(Oracle, x0, alpha0):
    import numpy as np
    from numpy.linalg import solve
    from numpy import dot
    from numpy import eye
    from numpy import outer
    from numpy import vdot
    from numpy.linalg import norm
    from time import process_time
    
    ##### Initialisation des variables

    iter_max = 250
    default_gradient_step = alpha0
    threshold = 0.000001
    
    gradient_norm_list = []
    gradient_step_list = []
    gradient_list = []
    critere_list = []
    x_list = []
    
    time_start = process_time()

    x = x0
    I = eye(len(x0))
    
    ##### Boucle sur les iterations
    
    for k in range(iter_max):
        
        
        # Valeur du critere et du gradient
        res = Oracle(x)
        critere = res[0]
        gradient = res[1]
        #hessien = res[2]
        
        # Test de convergence
        gradient_norm = norm(gradient)
        if gradient_norm <= threshold:
            break
                # Valeur du critere et du gradient
        
        # Direction de descente
        #direction_n = - solve(hessien, gradient)
        #print("direction_n",direction_n)
        
        # Formule de BFGS inverse for Direction de descente
        #print("k:",k)
        if k == 0:
            Wk = I 
            #print("Wk",Wk)
        else:
            #print("gradient",gradient)
            #print("gradient_list[-1]",gradient_list[-1])
            delta_xk = np.array([list(x - x_list[-1])]).transpose()
            delta_gk = np.array([list(gradient - gradient_list[-1])]).transpose()
            
            #print("delta_xk",delta_xk)
            #print("delta_gk",delta_gk)
            
            #print("(delta_xk@delta_gk.transpose())",(delta_xk@delta_gk.transpose()))
            
            A = I - np.multiply(delta_xk,delta_gk.transpose())/(delta_gk.transpose()@delta_xk)
            B = I - np.multiply(delta_gk,delta_xk.transpose())/(delta_gk.transpose()@delta_xk)
            C = (np.multiply(delta_xk,delta_xk.transpose()))/(delta_gk.transpose()@delta_xk)
            #print("A:",A)
            #print("B:",B)
            #print("C:",C)
                        
            Wk = A@Wk@B + C


            #print("Wk",Wk)
            #print("Hessien", hessien)
        direction = -Wk@gradient
        #print("direction",direction)
        
        # Direction de descente
        #direction = - solve(hessien, gradient)
        
        # conditions de Wolfe for step size
        res = Wolfe(default_gradient_step, x, direction, Oracle)
        gradient_step = res[0]
        
        #gradient_step =  default_gradient_step

        
        # Mise a jour des variables
        x_list.append(x)
        x = x + (gradient_step*direction)
        
        # Evolution du gradient, du pas, et du critere
        gradient_norm_list.append(gradient_norm)
        gradient_step_list.append(gradient_step)
        gradient_list.append(gradient)
        critere_list.append(critere)
    
    # Resultat de l'optimisation
    critere_opt = critere
    gradient_opt = gradient
    x_opt = x
    time_cpu = process_time() - time_start

    print()
    print('Iteration :', k)
    print('Temps CPU :', time_cpu)
    print('Critere optimal :', critere_opt)
    print('Norme du gradient :', norm(gradient_opt))
        
    # Visualisation de la convergence
    Visualg(gradient_norm_list, gradient_step_list, critere_list)
    
    return critere_opt, gradient_opt, x_opt,gradient_norm_list, gradient_step_list, critere_list

# %%
x0 = 0.1 * random.normal(size=n-md)
print()
print("MINIMISATION DU PROBLEME PRIMAL")
print()
print("ALGORITHME DE QUASI-NEWTON")
copt, gopt, xopt,gnl_QN, gsl_QN, cl_QN = BFGS_V(OraclePG, x0, 1)
#copt, gopt, xopt = Newton_N(OraclePH, x0, 1)
qopt, zopt, fopt, popt = HydrauliqueP(xopt, m, mr, md, r, pr, fd, Ar, AdI, B, q0)
Verification(A, qopt, zopt, fopt, popt)
# Out:
# MINIMISATION DU PROBLEME PRIMAL
#
# ALGORITHME DE QUASI-NEWTON
#
# Iteration : 26
# Temps CPU : 0.03125
# Critere optimal : -3.7340070480435745
# Norme du gradient : 2.2368469127979385e-07
# Verification des equations d'equilibre du reseau
# Sur les debits : 2.220446049250313e-16
# Sur les pressions : 1.4346945387266885e-07

# %% [markdown]
# ### Quasi Newton method with optimal stepsize by exact line search

# %%
def BFGS_L(Oracle, x0, alpha0):
    import numpy as np
    from numpy.linalg import solve
    from numpy import dot
    from numpy import eye
    from numpy import outer
    from numpy import vdot
    from numpy.linalg import norm
    from time import process_time
    
    ##### Initialisation des variables

    iter_max = 250
    gradient_step = alpha0
    threshold = 0.000001
    
    gradient_norm_list = []
    gradient_step_list = []
    gradient_list = []
    critere_list = []
    x_list = []
    
    time_start = process_time()

    x = x0
    I = eye(len(x0))
    
    ##### Boucle sur les iterations
    
    for k in range(iter_max):
        
        
        # Valeur du critere et du gradient
        res = Oracle(x)
        critere = res[0]
        gradient = res[1]
        #hessien = res[2]
        
        # Test de convergence
        gradient_norm = norm(gradient)
        if gradient_norm <= threshold:
            break
                # Valeur du critere et du gradient
        
        # Direction de descente
        #direction_n = - solve(hessien, gradient)
        #print("direction_n",direction_n)
        
        # Formule de BFGS inverse for Direction de descente
        #print("k:",k)
        if k == 0:
            Wk = I 
            #print("Wk",Wk)
        else:
            #print("gradient",gradient)
            #print("gradient_list[-1]",gradient_list[-1])
            delta_xk = np.array([list(x - x_list[-1])]).transpose()
            delta_gk = np.array([list(gradient - gradient_list[-1])]).transpose()
            
            #print("delta_xk",delta_xk)
            #print("delta_gk",delta_gk)
            
            #print("(delta_xk@delta_gk.transpose())",(delta_xk@delta_gk.transpose()))
            
            A = I - np.multiply(delta_xk,delta_gk.transpose())/(delta_gk.transpose()@delta_xk)
            B = I - np.multiply(delta_gk,delta_xk.transpose())/(delta_gk.transpose()@delta_xk)
            C = (np.multiply(delta_xk,delta_xk.transpose()))/(delta_gk.transpose()@delta_xk)
            #print("A:",A)
            #print("B:",B)
            #print("C:",C)
                        
            Wk = A@Wk@B + C


            #print("Wk",Wk)
            #print("Hessien", hessien)
        direction = -Wk@gradient
        #print("direction",direction)
        
        # Direction de descente
        #direction = - solve(hessien, gradient)
        
        # Exact Line search for step size
        if k > 0:
            res = Exact_line_earch(F,G,x,direction)
            
            #print(res)
            if res[0] is not None:
                gradient_step = res[0]
                
                
            else:
                gradient_step  =  gradient_step_list[-1]
                print(k)
                print(gradient_step)    
        
        
        #gradient_step =  default_gradient_step

        
        # Mise a jour des variables
        x_list.append(x)
        x = x + (gradient_step*direction)
        
        # Evolution du gradient, du pas, et du critere
        gradient_norm_list.append(gradient_norm)
        gradient_step_list.append(gradient_step)
        gradient_list.append(gradient)
        critere_list.append(critere)
    
    # Resultat de l'optimisation
    critere_opt = critere
    gradient_opt = gradient
    x_opt = x
    time_cpu = process_time() - time_start

    print()
    print('Iteration :', k)
    print('Temps CPU :', time_cpu)
    print('Critere optimal :', critere_opt)
    print('Norme du gradient :', norm(gradient_opt))
        
    # Visualisation de la convergence
    Visualg(gradient_norm_list, gradient_step_list, critere_list)
    
    return critere_opt, gradient_opt, x_opt,gradient_norm_list, gradient_step_list, critere_list

# %%
x0 = 0.1 * random.normal(size=n-md)
print()
print("MINIMISATION DU PROBLEME PRIMAL")
print()
print("ALGORITHME DE QUASI-NEWTON")
copt, gopt, xopt,gnl_QN, gsl_QN, cl_QN = BFGS_L(OraclePG, x0, 1)
#copt, gopt, xopt = Newton_N(OraclePH, x0, 1)
qopt, zopt, fopt, popt = HydrauliqueP(xopt, m, mr, md, r, pr, fd, Ar, AdI, B, q0)
Verification(A, qopt, zopt, fopt, popt)
# Out:
# MINIMISATION DU PROBLEME PRIMAL
#
# ALGORITHME DE QUASI-NEWTON
# 2
# 1.0
# 4
# 1.0
# 5
# 1.0
# 6
# 1.0
# 7
# 1.0
# 8
# 1.0
# 9
# 1.0
#
# Iteration : 249
# Temps CPU : 0.125
# Critere optimal : nan
# Norme du gradient : nan
# <ipython-input-12-ad96acd04c62>:3: RuntimeWarning: overflow encountered in multiply
#   return dot(q0+B@x, r*(q0+B@x)*abs(q0+B@x))/3 + dot(pr, Ar@(q0+B@x))
# <ipython-input-12-ad96acd04c62>:7: RuntimeWarning: overflow encountered in multiply
#   return B.transpose()@(r*(q0+B@x)*abs(q0+B@x))+B.transpose()@Ar.transpose()@pr
# <ipython-input-12-ad96acd04c62>:7: RuntimeWarning: invalid value encountered in matmul
#   return B.transpose()@(r*(q0+B@x)*abs(q0+B@x))+B.transpose()@Ar.transpose()@pr
# <ipython-input-7-1052a0dc5e65>:3: RuntimeWarning: invalid value encountered in matmul
#   gradient =B.transpose()@(r*(q0+B@qc)*abs(q0+B@qc))+B.transpose()@Ar.transpose()@pr
# <ipython-input-7-1052a0dc5e65>:4: RuntimeWarning: overflow encountered in multiply
#   critere = dot(q0+B@qc, r*(q0+B@qc)*abs(q0+B@qc))/3 + dot(pr, Ar@(q0+B@qc))
# <ipython-input-28-35117a7d4359>:67: RuntimeWarning: overflow encountered in multiply
#   C = (np.multiply(delta_xk,delta_xk.transpose()))/(delta_gk.transpose()@delta_xk)
# Verification des equations d'equilibre du reseau
# Sur les debits : nan
# Sur les pressions : nan

# %% [markdown]
# ### experiment of comparison

# %%
x0 = 0.1 * random.normal(size=n-md)
print()
print("MINIMISATION DU PROBLEME PRIMAL")
# Out:
# MINIMISATION DU PROBLEME PRIMAL

# %%
#x0
# Out:
# array([ 0.04314709,  0.01985427,  0.05378989,  0.01559173,  0.00550596,
#         0.1662339 , -0.18769806,  0.08017622,  0.00843705])

# %%
#x0 = np.array([ 0.04314709,  0.01985427,  0.05378989,  0.01559173,  0.00550596,
        0.1662339 , -0.18769806,  0.08017622,  0.00843705])

# %%
print("Gradient descending algorithm with fixed stepsize")
copt, gopt, xopt,gnl_GF, gsl_GF, cl_GF = Gradient_F(OraclePG, x0, 0.0005)
qopt, zopt, fopt, popt = HydrauliqueP(xopt, m, mr, md, r, pr, fd, Ar, AdI, B, q0)
Verification(A, qopt, zopt, fopt, popt)
# Out:
# Gradient descending algorithm with fixed stepsize
#
# Iteration : 4132
# Temps CPU : 0.15625
# Critere optimal : -3.7340070480435035
# Norme du gradient : 9.997526213612946e-07
# Verification des equations d'equilibre du reseau
# Sur les debits : 2.220446049250313e-16
# Sur les pressions : 9.997478762624468e-07

# %%
print("Newton method with fixed stepsize")
copt, gopt, xopt,gnl_NF, gsl_NF, cl_NF  = Newton_F(OraclePH, x0, 1)
qopt, zopt, fopt, popt = HydrauliqueP(xopt, m, mr, md, r, pr, fd, Ar, AdI, B, q0)
Verification(A, qopt, zopt, fopt, popt)
# Out:
# Newton method with fixed stepsize
#
# Iteration : 6
# Temps CPU : 0.0
# Critere optimal : -3.7340070480435763
# Norme du gradient : 7.380234782705488e-12
# Verification des equations d'equilibre du reseau
# Sur les debits : 1.6653345369377348e-16
# Sur les pressions : 6.854052048144155e-12

# %%
print("Gradient descending algorithm with optimal stepsize by Wolf algorithm")
copt, gopt, xopt,gnl_GV, gsl_GV, cl_GV = Gradient_V(OraclePG, x0, 1)
qopt, zopt, fopt, popt = HydrauliqueP(xopt, m, mr, md, r, pr, fd, Ar, AdI, B, q0)
Verification(A, qopt, zopt, fopt, popt)
# Out:
# Gradient descending algorithm with optimal stepsize by Wolf algorithm
#
# Iteration : 289
# Temps CPU : 0.171875
# Critere optimal : -3.734007048043516
# Norme du gradient : 9.460886226629044e-07
# Verification des equations d'equilibre du reseau
# Sur les debits : 8.326672684688674e-17
# Sur les pressions : 9.079087216479209e-07

# %%
print("Gradient descending algorithm with optimal stepsize by exact line search")
copt, gopt, xopt,gnl_GF, gsl_GF, cl_GF = Gradient_L(F,G,OraclePG, x0, 0.0005)
qopt, zopt, fopt, popt = HydrauliqueP(xopt, m, mr, md, r, pr, fd, Ar, AdI, B, q0)
Verification(A, qopt, zopt, fopt, popt)
# Out:
# Gradient descending algorithm with optimal stepsize by exact line search
#
# Iteration : 1273
# Temps CPU : 0.59375
# Critere optimal : -3.7340070480435212
# Norme du gradient : 8.829712268944229e-07
# Verification des equations d'equilibre du reseau
# Sur les debits : 1.249000902703301e-16
# Sur les pressions : 8.796955555112618e-07

# %%
print("Conjugation gradient descending algorithm with fixed stepsize")
copt, gopt, xopt,gnl_GC, gsl_GC, cl_GC = PolakRibiere(OraclePG, x0, 0.0005)
qopt, zopt, fopt, popt = HydrauliqueP(xopt, m, mr, md, r, pr, fd, Ar, AdI, B, q0)
Verification(A, qopt, zopt, fopt, popt)
# Out:
# Conjugation gradient descending algorithm with fixed stepsize
#
# Iteration : 4149
# Temps CPU : 0.171875
# Critere optimal : -3.734007048043507
# Norme du gradient : 9.988931249916381e-07
# Verification des equations d'equilibre du reseau
# Sur les debits : 1.6653345369377348e-16
# Sur les pressions : 9.98888379788454e-07

# %%
print("Conjugation gradient descending algorithm with optimal stepsize by Wolf algorithm")
copt, gopt, xopt,gnl_GC, gsl_GC, cl_GC = PolakRibiereV(OraclePG, x0, 1)
qopt, zopt, fopt, popt = HydrauliqueP(xopt, m, mr, md, r, pr, fd, Ar, AdI, B, q0)
Verification(A, qopt, zopt, fopt, popt)
# Out:
# Conjugation gradient descending algorithm with optimal stepsize by Wolf algorithm
#
# Iteration : 204
# Temps CPU : 0.15625
# Critere optimal : -3.7340070480435745
# Norme du gradient : 7.486717903239416e-07
# Verification des equations d'equilibre du reseau
# Sur les debits : 1.3877787807814457e-16
# Sur les pressions : 5.382908505602302e-07

# %%
print("Conjugation gradient descending algorithm with optimal stepsize by exact line search")
copt, gopt, xopt,gnl_GC, gsl_GC, cl_GC = PolakRibiereL(OraclePG, x0, 0.0005)
qopt, zopt, fopt, popt = HydrauliqueP(xopt, m, mr, md, r, pr, fd, Ar, AdI, B, q0)
Verification(A, qopt, zopt, fopt, popt)
# Out:
# Conjugation gradient descending algorithm with optimal stepsize by exact line search
# 4
# 0.0033991325534383434
# 5
# 0.0033991325534383434
# 6
# 0.0033991325534383434
# 7
# 0.0033991325534383434
# 8
# 0.0033991325534383434
# 9
# 0.0033991325534383434
# <ipython-input-12-ad96acd04c62>:3: RuntimeWarning: overflow encountered in multiply
#   return dot(q0+B@x, r*(q0+B@x)*abs(q0+B@x))/3 + dot(pr, Ar@(q0+B@x))
# <ipython-input-12-ad96acd04c62>:7: RuntimeWarning: overflow encountered in multiply
#   return B.transpose()@(r*(q0+B@x)*abs(q0+B@x))+B.transpose()@Ar.transpose()@pr
# <ipython-input-12-ad96acd04c62>:7: RuntimeWarning: invalid value encountered in matmul
#   return B.transpose()@(r*(q0+B@x)*abs(q0+B@x))+B.transpose()@Ar.transpose()@pr
# <ipython-input-7-1052a0dc5e65>:3: RuntimeWarning: invalid value encountered in matmul
#   gradient =B.transpose()@(r*(q0+B@qc)*abs(q0+B@qc))+B.transpose()@Ar.transpose()@pr
# <ipython-input-7-1052a0dc5e65>:4: RuntimeWarning: overflow encountered in multiply
#   critere = dot(q0+B@qc, r*(q0+B@qc)*abs(q0+B@qc))/3 + dot(pr, Ar@(q0+B@qc))
# Iteration : 999
# Temps CPU : 0.4375
# Critere optimal : nan
# Norme du gradient : nan
# Verification des equations d'equilibre du reseau
# Sur les debits : nan
# Sur les pressions : nan

# %%
print("Quasi Newton method with fixed stepsize")
copt, gopt, xopt,gnl_QN, gsl_QN, cl_QN = BFGS(OraclePG, x0, 1)
#copt, gopt, xopt = Newton_N(OraclePH, x0, 1)
qopt, zopt, fopt, popt = HydrauliqueP(xopt, m, mr, md, r, pr, fd, Ar, AdI, B, q0)
Verification(A, qopt, zopt, fopt, popt)
# Out:
# Quasi Newton method with fixed stepsize
#
# Iteration : 249
# Temps CPU : 0.015625
# Critere optimal : nan
# Norme du gradient : nan
# <ipython-input-24-dff377ab0e14>:65: RuntimeWarning: overflow encountered in multiply
#   A = I - np.multiply(delta_xk,delta_gk.transpose())/(delta_gk.transpose()@delta_xk)
# <ipython-input-24-dff377ab0e14>:65: RuntimeWarning: overflow encountered in matmul
#   A = I - np.multiply(delta_xk,delta_gk.transpose())/(delta_gk.transpose()@delta_xk)
# <ipython-input-24-dff377ab0e14>:65: RuntimeWarning: invalid value encountered in matmul
#   A = I - np.multiply(delta_xk,delta_gk.transpose())/(delta_gk.transpose()@delta_xk)
# <ipython-input-24-dff377ab0e14>:66: RuntimeWarning: overflow encountered in multiply
#   B = I - np.multiply(delta_gk,delta_xk.transpose())/(delta_gk.transpose()@delta_xk)
# <ipython-input-24-dff377ab0e14>:66: RuntimeWarning: overflow encountered in matmul
#   B = I - np.multiply(delta_gk,delta_xk.transpose())/(delta_gk.transpose()@delta_xk)
# <ipython-input-24-dff377ab0e14>:66: RuntimeWarning: invalid value encountered in matmul
#   B = I - np.multiply(delta_gk,delta_xk.transpose())/(delta_gk.transpose()@delta_xk)
# <ipython-input-24-dff377ab0e14>:67: RuntimeWarning: overflow encountered in matmul
#   C = (np.multiply(delta_xk,delta_xk.transpose()))/(delta_gk.transpose()@delta_xk)
# <ipython-input-24-dff377ab0e14>:67: RuntimeWarning: invalid value encountered in matmul
#   C = (np.multiply(delta_xk,delta_xk.transpose()))/(delta_gk.transpose()@delta_xk)
# Verification des equations d'equilibre du reseau
# Sur les debits : nan
# Sur les pressions : nan

# %%
print("Quasi Newton method with optimal stepsize by Wolf algorithm")
copt, gopt, xopt,gnl_QN, gsl_QN, cl_QN = BFGS_V(OraclePG, x0, 1)
#copt, gopt, xopt = Newton_N(OraclePH, x0, 1)
qopt, zopt, fopt, popt = HydrauliqueP(xopt, m, mr, md, r, pr, fd, Ar, AdI, B, q0)
Verification(A, qopt, zopt, fopt, popt)
# Out:
# Quasi Newton method with optimal stepsize by Wolf algorithm
#
# Iteration : 21
# Temps CPU : 0.015625
# Critere optimal : -3.7340070480435763
# Norme du gradient : 8.937140149481999e-07
# Verification des equations d'equilibre du reseau
# Sur les debits : 5.551115123125783e-17
# Sur les pressions : 7.822190219997083e-07

# %%
print("Quasi Newton method with optimal stepsize by exact line search")
copt, gopt, xopt,gnl_QN, gsl_QN, cl_QN = BFGS_L(OraclePG, x0, 1)
#copt, gopt, xopt = Newton_N(OraclePH, x0, 1)
qopt, zopt, fopt, popt = HydrauliqueP(xopt, m, mr, md, r, pr, fd, Ar, AdI, B, q0)
Verification(A, qopt, zopt, fopt, popt)
# Out:
# Quasi Newton method with optimal stepsize by exact line search
# 2
# 1.0
# 4
# 1.0
# 5
# 1.0
# 6
# 1.0
# 7
# 1.0
# 8
# 1.0
#
# Iteration : 249
# Temps CPU : 0.109375
# Critere optimal : nan
# Norme du gradient : nan
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\optimize\linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# <ipython-input-28-35117a7d4359>:65: RuntimeWarning: overflow encountered in multiply
#   A = I - np.multiply(delta_xk,delta_gk.transpose())/(delta_gk.transpose()@delta_xk)
# <ipython-input-28-35117a7d4359>:65: RuntimeWarning: overflow encountered in matmul
#   A = I - np.multiply(delta_xk,delta_gk.transpose())/(delta_gk.transpose()@delta_xk)
# <ipython-input-28-35117a7d4359>:65: RuntimeWarning: invalid value encountered in matmul
#   A = I - np.multiply(delta_xk,delta_gk.transpose())/(delta_gk.transpose()@delta_xk)
# <ipython-input-28-35117a7d4359>:66: RuntimeWarning: overflow encountered in multiply
#   B = I - np.multiply(delta_gk,delta_xk.transpose())/(delta_gk.transpose()@delta_xk)
# <ipython-input-28-35117a7d4359>:66: RuntimeWarning: overflow encountered in matmul
#   B = I - np.multiply(delta_gk,delta_xk.transpose())/(delta_gk.transpose()@delta_xk)
# <ipython-input-28-35117a7d4359>:66: RuntimeWarning: invalid value encountered in matmul
#   B = I - np.multiply(delta_gk,delta_xk.transpose())/(delta_gk.transpose()@delta_xk)
# <ipython-input-28-35117a7d4359>:67: RuntimeWarning: overflow encountered in matmul
#   C = (np.multiply(delta_xk,delta_xk.transpose()))/(delta_gk.transpose()@delta_xk)
# <ipython-input-28-35117a7d4359>:67: RuntimeWarning: invalid value encountered in matmul
#   C = (np.multiply(delta_xk,delta_xk.transpose()))/(delta_gk.transpose()@delta_xk)
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\optimize\linesearch.py:477: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# Verification des equations d'equilibre du reseau
# Sur les debits : nan
# Sur les pressions : nan

# %%
def Visualg2(gradient_lists, step_lists, criterere_lists): 

    import matplotlib.pyplot as plt 
    
    plt.subplot (2, 1, 1) 
    plt.gca().set_title ("Gradient norm during iterations") 
    plt.gca().set_yscale ('log') 
    plt.plot(gradient_lists[0], label = "Gradient norm_Algorithm1")
    plt.plot(gradient_lists[1], label = "Gradient norm_Algorithm2") 
    plt.plot(gradient_lists[2], label = "Gradient norm_Algorithm3") 
    
    plt.subplot (2, 1, 2) 
    
    plt.gca().set_title("Stepsize during iterations") 
    plt.gca().set_yscale('log')
    plt.plot(step_lists[0], label = "Step length_Algorithm1") 
    plt.plot(step_lists[1], label = "Step length_Algorithm2") 
    plt.plot(step_lists[2], label = "Step length_Algorithm3") 
    
    plt.tight_layout (rect = (0, 0, 1, 2)) 
    plt.show ()

# %%
gradient_lists = [gnl_GF,gnl_GV,gnl_GC]
step_lists = [gsl_GF, gsl_GV, gsl_GC]
criterere_lists = [cl_GF, cl_GV, cl_GC]

# %%
Visualg2(gradient_lists, step_lists, criterere_lists)

# %% [markdown]
# ## II. Résolution du problème dual

# %%
from HydrauliqueD import HydrauliqueD

# %% [markdown]
# ### II.a On écrit les oracles pour le problème dual d'optimisation :
#
# * **OracleDG** : calcul de la fonction et du gradient,
# * **OracleDH** : calcul de la fonction du gradient et du Hessien.

# %%
def OracleDG(pd):
    
    # ---> A COMPLETER
    # ---> A COMPLETER
    
    return critere, gradient

# %%
def OracleDH(pd):
    
    # ---> A COMPLETER
    # ---> A COMPLETER
    
    return critere, gradient, hessien

# %% [markdown]
# ### II.b On exécute tous les algorithmes d'optimisation déjà écrits

# %%
x0 = 100 + random.normal(size=md)
print()
print("MINIMISATION DU PROBLEME DUAL")
print()
print("ALGORITHME DU GRADIENT A PAS VARIABLE")
copt, gopt, xopt = Gradient_V(OracleDG, x0, 5)
qopt, zopt, fopt, popt = HydrauliqueD(xopt, m, mr, r, pr, fd, A, Ar)
Verification(A, qopt, zopt, fopt, popt)

# %%
x0 = 100 + random.normal(size=md)
print()
print("MINIMISATION DU PROBLEME DUAL")
print()
print("ALGORITHME DU GRADIENT CONJUGUE")
copt, gopt, xopt = PolakRibiere(OracleDG, x0, 5)
qopt, zopt, fopt, popt = HydrauliqueD(xopt, m, mr, r, pr, fd, A, Ar)
Verification(A, qopt, zopt, fopt, popt)

# %%
x0 = 100 + random.normal(size=md)
print()
print("MINIMISATION DU PROBLEME DUAL")
print()
print("ALGORITHME DE QUASI-NEWTON")
copt, gopt, xopt = BFGS(OracleDG, x0, 1)
qopt, zopt, fopt, popt = HydrauliqueD(xopt, m, mr, r, pr, fd, A, Ar)
Verification(A, qopt, zopt, fopt, popt)

# %%
x0 = 100 + random.normal(size=md)
print()
print("MINIMISATION DU PROBLEME DUAL")
print()
print("ALGORITHME DE NEWTON A PAS VARIABLE")
copt, gopt, xopt = Newton_V(OracleDH, x0, 1)
qopt, zopt, fopt, popt = HydrauliqueD(xopt, m, mr, r, pr, fd, A, Ar)
Verification(A, qopt, zopt, fopt, popt)

# %% [markdown]
# ## III. Résolution de grands réseaux (facultatif)

# %% [markdown]
# ### On charge dans l'environnement les données du problème
#
# Ces données correspondent à un réseau de taille paramétrable.

# %%
from Probleme_P import *
from Structures_S import *

# %% [markdown]
# ### III.a On écrit des oracles primal et dual avec Hessien creux

# %%
def OraclePHS(qc):
    
    # ---> A COMPLETER
    # ---> A COMPLETER
    
    return critere, gradient, hessien

# %%
def OracleDHS(pd):
    
    # ---> A COMPLETER
    # ---> A COMPLETER
    
    return critere, gradient, hessien

# %% [markdown]
# ### III.b On écrit un algorithme de Newton exploitant le creux

# %%
def Newton_S(Oracle, x0, alpha0):
    
    from numpy.linalg import norm
    from scipy.sparse.linalg import spsolve
    from time import process_time
    
    ##### Initialisation des variables  
    
    iter_max = 100
    default_gradient_step = alpha0
    threshold = 0.000001
    
    gradient_norm_list = []
    gradient_step_list = []
    critere_list = []

    time_start = process_time()
    
    x = x0

    ##### Boucle sur les iterations
    
    for k in range(iter_max):
        
        # ---> A COMPLETER
        # ---> A COMPLETER
           
    ##### Resultats de l'optimisation
    
    critere_opt = critere
    gradient_opt = gradient
    x_opt = x
    time_cpu = process_time() - time_start

    print()
    print('Iteration :', k)
    print('Temps CPU :', time_cpu)
    print('Critere optimal :', critere_opt)
    print('Norme du gradient :', norm(gradient_opt))
    
    # Visualisation de la convergence
    Visualg(gradient_norm_list, gradient_step_list, critere_list)
    
    return critere_opt, gradient_opt, x_opt

# %% [markdown]
# ### III.c On résoud le problème dans le primal et dans le dual

# %%
x0 = 0.1 * random.normal(size=n-md)
print()
print("MINIMISATION DU PROBLEME PRIMAL DE GRANDE TAILLE")
print()
print("ALGORITHME DE NEWTON A PAS VARIABLE")
copt, gopt, xopt = Newton_S(OraclePHS, x0, 1)
qopt, zopt, fopt, popt = HydrauliqueP(xopt, m, mr, md, r, pr, fd, Ar, AdI, B, q0)
Verification(A, qopt, zopt, fopt, popt)

# %%
x0 = 100 + random.normal(size=md)
print()
print("MINIMISATION DU PROBLEME DUAL DE GRANDE TAILLE")
print()
print("ALGORITHME DE NEWTON A PAS VARIABLE")
copt, gopt, xopt = Newton_S(OracleDHS, x0, 1)
qopt, zopt, fopt, popt = HydrauliqueD(xopt, m, mr, r, pr, fd, A, Ar)
Verification(A, qopt, zopt, fopt, popt)
